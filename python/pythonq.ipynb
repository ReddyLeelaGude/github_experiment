# %%
l = [9,0,67,0,8,8]
set(l)
# Out:
# {0, 8, 9, 67}

# %%
s = {89,90,6,'p',7888888,4556,9}
s
# Out:
# {4556, 6, 7888888, 89, 9, 90, 'p'}

# %%
s = {89,90,6,'p',7888888,4556,9}
s
# Out:
# {4556, 6, 7888888, 89, 9, 90, 'p'}

# %%
s={9,9,0}
s.add(8)
s
# Out:
# {0, 8, 9}

# %%
s={9,9,0}
s.add([7,6,8])
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 s={9,9,0}
# ----> 2 s.add([7,6,8])
#       3 s
#
# TypeError: unhashable type: 'list'

# %%
s={9,9,0}
s.add((7,6,8))
s
# Out:
# {(7, 6, 8), 0, 9}

# %%
s={9,9,0}
s.update(7)
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 s={9,9,0}
# ----> 2 s.update(7)
#       3 s
#
# TypeError: 'int' object is not iterable

# %%
s={9,9,0}
s.update([7,6,8])
s
# Out:
# {0, 6, 7, 8, 9}

# %%
s={9,8,0}
s.remove(9)
s
# Out:
# {0, 8}

# %%
s={9,8,0}
s.discard(90) # no error is shown, if the element is not present in the set  
s
# Out:
# {0, 8, 9}

# %%
s={9,8,0}
s.pop()
s
# Out:
# {0, 9}

# %%
l = [2,3,6,9,4]
l.pop()
l
# Out:
# [2, 3, 6, 9]
